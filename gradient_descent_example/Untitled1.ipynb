# %%
import numpy as np
import matplotlib.pyplot as plt

# Step function
def step_function(z):
    return 1 if z >= 0 else 0

# Perceptron class
class Perceptron:
    def __init__(self, learning_rate=0.01, n_iterations=100000import numpy as np
from sklearn.linear_model import Perceptron
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Data generation
np.random.seed(0)
m = 100
age = np.random.uniform(18, 70, m)
income = np.random.uniform(20, 100, m)
labels = (age > 35) & (income > 50)
y_train = labels.astype(int)
X_train = np.c_[age, income]

# Normalize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Train perceptron
perceptron = Perceptron(max_iter=1000, eta0=0.01, random_state=0)
perceptron.fit(X_train_scaled, y_train)

# Test prediction
test_age, test_income = 27, 27
test_point = scaler.transform([[test_age, test_income]])
prediction = perceptron.predict(test_point)[0]
print(f"Age = {test_age}, Income = {test_income}, Prediction = {prediction}")

# Plot decision boundary
age_range = np.linspace(18, 70, 100)
income_boundary = (-perceptron.intercept_[0] - perceptron.coef_[0][0] * 
                   scaler.transform(np.c_[age_range, np.zeros(100)])[:, 0]) / perceptron.coef_[0][1]
 boundary = scaler.inverse_transform(np.c_[np.zeros(100), income_boundary])[:, 1]

plt.scatter(age[y_train == 0], income[y_train == 0], c='red', label='Class 0')
plt.scatter(age[y_train == 1], income[y_train == 1], c='blue', label='Class 1')
plt.plot(age_range, income_boundary, 'g-', label='Perceptron Boundary')
plt.xlabel('Age')
plt.ylabel('Income')
plt.legend()
plt.title('Scikit-learn Perceptron Decision Boundary')
plt.show()

# Accuracy
y_pred = perceptron.predict(X_train_scaled)
print(f"Accuracy: {accuracy_score(y_train, y_pred):.2f}")):
        self.lr = learning_rate
        self.n_iterations = n_iterations
        self.weights = None
        self.bias = None
    
    def fit(self, X, y):
        n_samples, n_features = X.shape
        # Initialize weights and bias to zeros
        self.weights = np.zeros(n_features)
        self.bias = 0
        
        # Training loop
        for _ in range(self.n_iterations):
            for idx, x_i in enumerate(X):
                # Compute linear output
                linear_output = np.dot(x_i, self.weights) + self.bias
                y_predicted = step_function(linear_output)
                
                # Update rule: if misclassified, adjust weights and bias
                update = self.lr * (y[idx] - y_predicted)
                self.weights += update * x_i
                self.bias += update
    
    def predict(self, X):
        linear_output = np.dot(X, self.weights) + self.bias
        return np.array([step_function(z) for z in linear_output])

# Data generation (same as before)
np.random.seed(0)
m = 100
age = np.random.uniform(18, 70, m)
income = np.random.uniform(20, 100, m)
labels = (age > 35) & (income > 50)
y_train = labels.astype(int)
X_train = np.c_[age, income]  # No bias column needed (handled internally)

# Normalize features (optional, but helps convergence)
X_train = (X_train - X_train.mean(axis=0)) / X_train.std(axis=0)

# Train perceptron
perceptron = Perceptron(learning_rate=0.01, n_iterations=1000)
perceptron.fit(X_train, y_train)

# Test prediction
test_age, test_income = 27, 27
test_point = np.array([(test_age - X_train[:, 0].mean()) / X_train[:, 0].std(),
                       (test_income - X_train[:, 1].mean()) / X_train[:, 1].std()])
prediction = perceptron.predict([test_point])[0]
print(f"Age = {test_age}, Income = {test_income}, Prediction = {prediction}")

# Plot decision boundary
age_range = np.linspace(18, 70, 100)
income_boundary = (-perceptron.bias - perceptron.weights[0] * 
                   (age_range - X_train[:, 0].mean()) / X_train[:, 0].std()) / perceptron.weights[1]
income_boundary = income_boundary * X_train[:, 1].std() + X_train[:, 1].mean()
import numpy as np
from sklearn.linear_model import Perceptron
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Data generation
np.random.seed(0)
m = 100
age = np.random.uniform(18, 70, m)
income = np.random.uniform(20, 100, m)
labels = (age > 35) & (income > 50)
y_train = labels.astype(int)
X_train = np.c_[age, income]

# Normalize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Train perceptron
perceptron = Perceptron(max_iter=1000, eta0=0.01, random_state=0)
perceptron.fit(X_train_scaled, y_train)

# Test prediction
test_age, test_income = 27, 27
test_point = scaler.transform([[test_age, test_income]])
prediction = perceptron.predict(test_point)[0]
print(f"Age = {test_age}, Income = {test_income}, Prediction = {prediction}")

# Plot decision boundary
age_range = np.linspace(18, 70, 100)
income_boundary = (-perceptron.intercept_[0] - perceptron.coef_[0][0] * 
                   scaler.transform(np.c_[age_range, np.zeros(100)])[:, 0]) / perceptron.coef_[0][1]
 boundary = scaler.inverse_transform(np.c_[np.zeros(100), income_boundary])[:, 1]

plt.scatter(age[y_train == 0], income[y_train == 0], c='red', label='Class 0')
plt.scatter(age[y_train == 1], income[y_train == 1], c='blue', label='Class 1')
plt.plot(age_range, income_boundary, 'g-', label='Perceptron Boundary')
plt.xlabel('Age')
plt.ylabel('Income')
plt.legend()
plt.title('Scikit-learn Perceptron Decision Boundary')
plt.show()

# Accuracy
y_pred = perceptron.predict(X_train_scaled)
print(f"Accuracy: {accuracy_score(y_train, y_pred):.2f}")
plt.scatter(age[y_train == 0], income[y_train == 0], c='red', label='Class 0')
plt.scatter(age[y_train == 1], income[y_train == 1], c='blue', label='Class 1')
plt.plot(age_range, income_boundary, 'g-', label='Perceptron Boundary')
plt.xlabel('Age')
plt.ylabel('Income')
plt.legend()
plt.title('Perceptron Decision Boundary')
plt.show()

# Accuracy
y_pred = perceptron.predict(X_train)
accuracy = np.mean(y_pred == y_train)
print(f"Accuracy: {accuracy:.2f}")
# Out:
#   Cell In[4], line 10
#     def __init__(self, learning_rate=0.01, n_iterations=100000import numpy as np
#                                                              ^
# SyntaxError: invalid decimal literal
